# %% [markdown]
# # Modul 1 Data Science Einführung
# ## Markdown Features
#   - Markdown
#     - Aufzählungen
#     - **Überschriften**
#     - __Fetter Text__
#     - _Kursiver Text_

# %%
x = 7

# %%
x * 2 # Zugriff auf vorherige Zeile
# Out:
# 14

# %%
x
# Out:
# 7

# %% [markdown]
# ## Tabelle darstellen

# %%
import pandas as pd

# %%
pd.DataFrame({"Spalte1":[1,2,3], "Spalte2":[1,6,9],"Spalte3":[4,2,5]})
# Out:
#    Spalte1  Spalte2  Spalte3
# 0        1        1        4
# 1        2        6        2
# 2        3        9        5

# %% [markdown]
# ## Diagramm darstellen

# %%
import matplotlib.pyplot as plt

# %%
y = [3, 4, 8, 2, 1, 2, -1]
plt.plot(y)
